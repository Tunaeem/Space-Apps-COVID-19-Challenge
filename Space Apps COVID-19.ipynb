# %% [markdown]
# ### Space Apps COVID-19 / Where There’s a Link, There’s a Way Challenge
#
# #### MOPITT Link: https://mopitt.physics.utoronto.ca/
# #### Dataset Link: ftp://ftp.asc-csa.gc.ca/users/OpenData_DonneesOuvertes/pub/MOPITT/

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob
import os

# %%
path =r'/home/tuna/Downloads/mar-19' # use your path.
allFiles = glob. glob(path + "/*.csv")
frame = pd. DataFrame()
list_ = []
for file_ in allFiles:
    df = pd. read_csv(file_,index_col=None, header=0)
    list_. append(df)
frame = pd. concat(list_,ignore_index=True)

# %%
frame
# Out:
#          # Latitude   Longitude   COTotalColumn  COMixingRatio surface  \
# 0          -80.7565     29.4190    7.034130e+17                73.3627
# 1          -80.8823     30.4567    6.731520e+17                67.5439
# 2          -81.0646     27.6064    7.071930e+17                72.1516
# 3          -81.1970     28.6662    7.319010e+17                73.4702
# 4          -81.3268     29.7554    6.919730e+17                69.2818
# ...             ...         ...             ...                    ...
# 2450665    -70.1850    128.1830    6.471930e+17                54.6243
# 2450666    -69.9998    128.4980    6.750390e+17                68.8503
# 2450667    -69.8141    128.8070    8.116750e+17               112.3030
# 2450668    -69.9777    126.9790    6.400460e+17                63.2130
# 2450669    -69.6028    127.6320    8.313090e+17               112.3900
#
#          COMixingRatio 900hPa  COMixingRatio 800hPa  COMixingRatio 700hPa  \
# ...

# %%
mar_19 = frame[['# Latitude', ' Longitude', 'COMixingRatio surface', 'RetrievedSurfaceTemperature ']]

# %%
mar_19
# Out:
#          # Latitude   Longitude  COMixingRatio surface  \
# 0          -80.7565     29.4190                73.3627
# 1          -80.8823     30.4567                67.5439
# 2          -81.0646     27.6064                72.1516
# 3          -81.1970     28.6662                73.4702
# 4          -81.3268     29.7554                69.2818
# ...             ...         ...                    ...
# 2450665    -70.1850    128.1830                54.6243
# 2450666    -69.9998    128.4980                68.8503
# 2450667    -69.8141    128.8070               112.3030
# 2450668    -69.9777    126.9790                63.2130
# 2450669    -69.6028    127.6320               112.3900
#
#          RetrievedSurfaceTemperature
# 0                             201.485
# 1                             200.638
# 2                             202.999
# 3                             202.573
# 4                             202.937
# ...                               ...
# ...

# %%
#### New DataFrame to compare with country's coordinate values
last_mar_19 = pd.DataFrame

#CHI
last_mar_19 = mar_19[(mar_19["# Latitude"] >= 20.14) & (mar_19["# Latitude"] <= 53.33) & 
       (mar_19[" Longitude"] <= 134.78) & (mar_19[" Longitude"] >= 73.51)]

#ITA
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= 47.267) & (mar_19["# Latitude"] <= 54.914) & 
       #(mar_19[" Longitude"] <= 15.04) & (mar_19[" Longitude"] >= 5.85)]

#BRE
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= -33.824) & (mar_19["# Latitude"] <= 5.314) & 
       #(mar_19[" Longitude"] <= -34.70) & (mar_19[" Longitude"] >= -74.077)]

#AUS
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= -43.66) & (mar_19["# Latitude"] <= -10.57) & 
       #(mar_19[" Longitude"] <= 153.75) & (mar_19[" Longitude"] >= 112.89)]

#CAN
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= 41.60) & (mar_19["# Latitude"] <= 70.63) & 
       #(mar_19[" Longitude"] <= -55.55) & (mar_19[" Longitude"] >= -141.02)]

#TR
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= 36) & (mar_19["# Latitude"] <= 42) & 
       #(mar_19[" Longitude"] <= 45) & (mar_19[" Longitude"] >= 26)]

# %%
# Surface Temperature is Kelvin, convert to Celcius
df = last_mar_19.copy()
df["RetrievedSurfaceTemperature "] = df["RetrievedSurfaceTemperature "]-273.15

# %%
last_mar_19 = df
last_mar_19
# Out:
#          # Latitude   Longitude  COMixingRatio surface  \
# 28506       53.2472    130.3330                151.140
# 28507       53.3030    129.6190                140.212
# 28509       53.3166    128.4490                138.062
# 28510       53.1051    129.8760                153.883
# 28511       53.3084    129.9440                120.884
# ...             ...         ...                    ...
# 2364816     52.8735     77.5147                140.252
# 2364817     52.4511     77.7305                165.976
# 2364818     52.2390     77.8351                157.848
# 2364824     53.3083     76.7812                158.303
# 2364828     53.2014     77.2664                148.973
#
#          RetrievedSurfaceTemperature
# 28506                         -12.612
# 28507                         -11.218
# 28509                         -11.145
# 28510                         -10.238
# 28511                         -10.248
# ...                               ...
# ...

# %%
last_mar_19.to_csv(r'/home/tuna/Downloads/mar-19/chi_mar_19.csv')

# %%
##########################################################################################################
##########################################################################################################
##########################################################################################################

# %%
path =r'/home/tuna/Downloads/mar-20' # use your path.
allFiles = glob. glob(path + "/*.csv")
frame = pd. DataFrame()
list_ = []
for file_ in allFiles:
    df = pd. read_csv(file_,index_col=None, header=0)
    list_. append(df)
frame = pd. concat(list_,ignore_index=True)

# %%
frame
# Out:
#          # Latitude   Longitude   COTotalColumn  COMixingRatio surface  \
# 0           62.5151     166.939    2.290060e+18                158.791
# 1           62.7335     167.037    2.317160e+18                169.739
# 2           62.9519     167.138    2.232560e+18                161.772
# 3           62.3917     167.935    2.108190e+18                159.310
# 4           62.6030     168.039    1.949220e+18                144.441
# ...             ...         ...             ...                    ...
# 2107387     81.7539    -134.333    2.135860e+18                115.893
# 2107388     82.0411    -136.956    2.217270e+18                136.136
# 2107389     82.1228    -135.600    2.215870e+18                132.786
# 2107390     83.1674    -142.000    2.218240e+18                130.314
# 2107391     83.5642    -144.236    2.258950e+18                132.035
#
#          COMixingRatio 900hPa  COMixingRatio 800hPa  COMixingRatio 700hPa  \
# ...

# %%
mar_20 = frame[['# Latitude', ' Longitude', 'COMixingRatio surface', 'RetrievedSurfaceTemperature ']]

# %%
mar_20
# Out:
#          # Latitude   Longitude  COMixingRatio surface  \
# 0           62.5151     166.939                158.791
# 1           62.7335     167.037                169.739
# 2           62.9519     167.138                161.772
# 3           62.3917     167.935                159.310
# 4           62.6030     168.039                144.441
# ...             ...         ...                    ...
# 2107387     81.7539    -134.333                115.893
# 2107388     82.0411    -136.956                136.136
# 2107389     82.1228    -135.600                132.786
# 2107390     83.1674    -142.000                130.314
# 2107391     83.5642    -144.236                132.035
#
#          RetrievedSurfaceTemperature
# 0                             246.027
# 1                             244.312
# 2                             244.582
# 3                             244.719
# 4                             248.422
# ...                               ...
# ...

# %%
#### New DataFrame to compare with Canada coordinate values
last_mar_20 = pd.DataFrame

#CHI
last_mar_19 = mar_19[(mar_19["# Latitude"] >= 20.14) & (mar_19["# Latitude"] <= 53.33) & 
       (mar_19[" Longitude"] <= 134.78) & (mar_19[" Longitude"] >= 73.51)]

#ITA
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= 47.267) & (mar_19["# Latitude"] <= 54.914) & 
       #(mar_19[" Longitude"] <= 15.04) & (mar_19[" Longitude"] >= 5.85)]

#BRE
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= -33.824) & (mar_19["# Latitude"] <= 5.314) & 
       #(mar_19[" Longitude"] <= -34.70) & (mar_19[" Longitude"] >= -74.077)]

#AUS
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= -43.66) & (mar_19["# Latitude"] <= -10.57) & 
       #(mar_19[" Longitude"] <= 153.75) & (mar_19[" Longitude"] >= 112.89)]

#CAN
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= 41.60) & (mar_19["# Latitude"] <= 70.63) & 
       #(mar_19[" Longitude"] <= -55.55) & (mar_19[" Longitude"] >= -141.02)]

#TR
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= 36) & (mar_19["# Latitude"] <= 42) & 
       #(mar_19[" Longitude"] <= 45) & (mar_19[" Longitude"] >= 26)]

# %%
# Surface Temperature is Kelvin, convert to Celcius
df = last_mar_20.copy()
df["RetrievedSurfaceTemperature "] = df["RetrievedSurfaceTemperature "]-273.15

# %%
last_mar_20 = df
last_mar_20
# Out:
#          # Latitude   Longitude  COMixingRatio surface  \
# 18850       34.8025    134.6500                223.558
# 18851       35.0069    134.6880                174.058
# 18861       34.1730    134.7720                172.307
# 18865       34.2078    134.2560                160.225
# 18866       34.4140    134.2930                188.538
# ...             ...         ...                    ...
# 2040849     49.5269     74.3548                185.065
# 2040850     49.3068     74.4109                153.066
# 2040943     51.0884     73.8482                165.376
# 2040944     50.8683     73.9076                150.226
# 2040955     51.6489     73.6471                170.461
#
#          RetrievedSurfaceTemperature
# 18850                          15.828
# 18851                          12.628
# 18861                          14.762
# 18865                          17.692
# 18866                          11.865
# ...                               ...
# ...

# %%
last_mar_20.to_csv(r'/home/tuna/Downloads/mar-20/chi_mar_20.csv')

# %%
##########################################################################################################
##########################################################################################################
##########################################################################################################

# %%
path =r'/home/tuna/Downloads/apr-20' # use your path.
allFiles = glob. glob(path + "/*.csv")
frame = pd. DataFrame()
list_ = []
for file_ in allFiles:
    df = pd. read_csv(file_,index_col=None, header=0)
    list_. append(df)
frame = pd. concat(list_,ignore_index=True)

# %%
frame
# Out:
#          # Latitude   Longitude   COTotalColumn  COMixingRatio surface  \
# 0          -77.2124     38.1937    8.122100e+17               114.1680
# 1          -77.3206     39.1075    6.286330e+17                73.5340
# 2          -77.4256     40.0366    6.092140e+17                66.9328
# 3          -77.6289     37.0024    6.080900e+17                66.3766
# 4          -77.7382     37.9087    7.117630e+17                87.8083
# ...             ...         ...             ...                    ...
# 5187540    -69.1621    128.2840    8.033390e+17                86.9726
# 5187541    -69.5031    126.1050    8.489400e+17               105.4670
# 5187542    -69.3122    126.4420    8.080350e+17                93.6127
# 5187543    -69.1208    126.7740    9.186620e+17               112.8280
# 5187544    -68.9283    127.1000    7.116670e+17                64.8660
#
#          COMixingRatio 900hPa  COMixingRatio 800hPa  COMixingRatio 700hPa  \
# ...

# %%
apr_20 = frame[['# Latitude', ' Longitude', 'COMixingRatio surface', 'RetrievedSurfaceTemperature ']]

# %%
apr_20
# Out:
#          # Latitude   Longitude  COMixingRatio surface  \
# 0          -77.2124     38.1937               114.1680
# 1          -77.3206     39.1075                73.5340
# 2          -77.4256     40.0366                66.9328
# 3          -77.6289     37.0024                66.3766
# 4          -77.7382     37.9087                87.8083
# ...             ...         ...                    ...
# 5187540    -69.1621    128.2840                86.9726
# 5187541    -69.5031    126.1050               105.4670
# 5187542    -69.3122    126.4420                93.6127
# 5187543    -69.1208    126.7740               112.8280
# 5187544    -68.9283    127.1000                64.8660
#
#          RetrievedSurfaceTemperature
# 0                             171.880
# 1                             206.203
# 2                             200.810
# 3                             171.530
# 4                             196.919
# ...                               ...
# ...

# %%
#### New DataFrame to compare with Canada coordinate values
last_apr_20 = pd.DataFrame

#CHI
last_mar_19 = mar_19[(mar_19["# Latitude"] >= 20.14) & (mar_19["# Latitude"] <= 53.33) & 
       (mar_19[" Longitude"] <= 134.78) & (mar_19[" Longitude"] >= 73.51)]

#ITA
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= 47.267) & (mar_19["# Latitude"] <= 54.914) & 
       #(mar_19[" Longitude"] <= 15.04) & (mar_19[" Longitude"] >= 5.85)]

#BRE
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= -33.824) & (mar_19["# Latitude"] <= 5.314) & 
       #(mar_19[" Longitude"] <= -34.70) & (mar_19[" Longitude"] >= -74.077)]

#AUS
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= -43.66) & (mar_19["# Latitude"] <= -10.57) & 
       #(mar_19[" Longitude"] <= 153.75) & (mar_19[" Longitude"] >= 112.89)]

#CAN
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= 41.60) & (mar_19["# Latitude"] <= 70.63) & 
       #(mar_19[" Longitude"] <= -55.55) & (mar_19[" Longitude"] >= -141.02)]

#TR
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= 36) & (mar_19["# Latitude"] <= 42) & 
       #(mar_19[" Longitude"] <= 45) & (mar_19[" Longitude"] >= 26)]

# %%
# Surface Temperature is Kelvin, convert to Celcius
df = last_apr_20.copy()
df["RetrievedSurfaceTemperature "] = df["RetrievedSurfaceTemperature "]-273.15

# %%
last_apr_20 = df
last_apr_20
# Out:
#          # Latitude   Longitude  COMixingRatio surface  \
# 25834       53.2456    128.1940                216.986
# 25837       53.1306    128.8300                219.391
# 25838       53.3263    128.9070                213.165
# 25840       53.0119    129.4570                232.854
# 25841       53.2068    129.5360                235.893
# ...             ...         ...                    ...
# 5106206     53.1655     73.6840                155.786
# 5106207     52.9506     73.7960                154.994
# 5106210     53.2699     74.0586                155.705
# 5106211     53.0581     74.1676                154.720
# 5106215     53.2367     74.9044                153.694
#
#          RetrievedSurfaceTemperature
# 25834                          10.111
# 25837                           8.043
# 25838                           8.620
# 25840                           8.546
# 25841                           7.511
# ...                               ...
# ...

# %%
last_apr_20.to_csv(r'/home/tuna/Downloads/apr-20/chi_apr_20.csv')

# %%
##########################################################################################################
##########################################################################################################
##########################################################################################################

# %%
path =r'/home/tuna/Downloads/apr-19' # use your path.
allFiles = glob. glob(path + "/*.csv")
frame = pd. DataFrame()
list_ = []
for file_ in allFiles:
    df = pd. read_csv(file_,index_col=None, header=0)
    list_. append(df)
frame = pd. concat(list_,ignore_index=True)

# %%
frame
# Out:
#          # Latitude   Longitude   COTotalColumn  COMixingRatio surface  \
# 0          -80.7565     29.4190    7.034130e+17                73.3627
# 1          -80.8823     30.4567    6.731520e+17                67.5439
# 2          -81.0646     27.6064    7.071930e+17                72.1516
# 3          -81.1970     28.6662    7.319010e+17                73.4702
# 4          -81.3268     29.7554    6.919730e+17                69.2818
# ...             ...         ...             ...                    ...
# 5154972    -70.1850    128.1830    6.471930e+17                54.6243
# 5154973    -69.9998    128.4980    6.750390e+17                68.8503
# 5154974    -69.8141    128.8070    8.116750e+17               112.3030
# 5154975    -69.9777    126.9790    6.400460e+17                63.2130
# 5154976    -69.6028    127.6320    8.313090e+17               112.3900
#
#          COMixingRatio 900hPa  COMixingRatio 800hPa  COMixingRatio 700hPa  \
# ...

# %%
apr_19 = frame[['# Latitude', ' Longitude', 'COMixingRatio surface', 'RetrievedSurfaceTemperature ']]

# %%
apr_19
# Out:
#          # Latitude   Longitude  COMixingRatio surface  \
# 0          -80.7565     29.4190                73.3627
# 1          -80.8823     30.4567                67.5439
# 2          -81.0646     27.6064                72.1516
# 3          -81.1970     28.6662                73.4702
# 4          -81.3268     29.7554                69.2818
# ...             ...         ...                    ...
# 5154972    -70.1850    128.1830                54.6243
# 5154973    -69.9998    128.4980                68.8503
# 5154974    -69.8141    128.8070               112.3030
# 5154975    -69.9777    126.9790                63.2130
# 5154976    -69.6028    127.6320               112.3900
#
#          RetrievedSurfaceTemperature
# 0                             201.485
# 1                             200.638
# 2                             202.999
# 3                             202.573
# 4                             202.937
# ...                               ...
# ...

# %%
#### New DataFrame to compare with Canada coordinate values
last_apr_19 = pd.DataFrame

#CHI
last_mar_19 = mar_19[(mar_19["# Latitude"] >= 20.14) & (mar_19["# Latitude"] <= 53.33) & 
       (mar_19[" Longitude"] <= 134.78) & (mar_19[" Longitude"] >= 73.51)]

#ITA
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= 47.267) & (mar_19["# Latitude"] <= 54.914) & 
       #(mar_19[" Longitude"] <= 15.04) & (mar_19[" Longitude"] >= 5.85)]

#BRE
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= -33.824) & (mar_19["# Latitude"] <= 5.314) & 
       #(mar_19[" Longitude"] <= -34.70) & (mar_19[" Longitude"] >= -74.077)]

#AUS
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= -43.66) & (mar_19["# Latitude"] <= -10.57) & 
       #(mar_19[" Longitude"] <= 153.75) & (mar_19[" Longitude"] >= 112.89)]

#CAN
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= 41.60) & (mar_19["# Latitude"] <= 70.63) & 
       #(mar_19[" Longitude"] <= -55.55) & (mar_19[" Longitude"] >= -141.02)]

#TR
#last_mar_19 = mar_19[(mar_19["# Latitude"] >= 36) & (mar_19["# Latitude"] <= 42) & 
       #(mar_19[" Longitude"] <= 45) & (mar_19[" Longitude"] >= 26)]

# %%
# Surface Temperature is Kelvin, convert to Celcius
df = last_apr_19.copy()
df["RetrievedSurfaceTemperature "] = df["RetrievedSurfaceTemperature "]-273.15

# %%
last_apr_19 = df
last_apr_19
# Out:
#          # Latitude   Longitude  COMixingRatio surface  \
# 26142       50.4243    123.5310                168.472
# 26143       48.7315    132.3540                197.042
# 26144       48.9470    132.4500                278.315
# 26145       49.1622    132.5480                202.940
# 26146       48.7769    131.9840                224.974
# ...             ...         ...                    ...
# 5074392     52.5899     74.9522                136.683
# 5074393     52.7774     74.4431                146.952
# 5074394     52.5654     74.5493                147.856
# 5074395     52.7423     75.2790                143.277
# 5074396     52.9054     75.9753                144.840
#
#          RetrievedSurfaceTemperature
# 26142                          12.880
# 26143                          20.518
# 26144                          19.056
# 26145                          14.913
# 26146                          21.777
# ...                               ...
# ...

# %%
last_apr_19.to_csv(r'/home/tuna/Downloads/apr-19/chi_apr_19.csv')
